# %%
for i in range(21):
    raw = pd.read_csv(r'C:\Users\com\[MSB535]\data\Breau Data\{}\{}.csv'.format(2000+i,2000+i))
    raw['YEAR'] = 2000+i
    raw = raw.drop([raw.columns[7]], axis = 1)
    if i == 0 :
        data = raw
    else:
        data = pd.concat([data,raw]) 
data.to_csv(r'C:\Users\com\[MSB535]\data\Breau Data\Data.csv')

# %%
url = "https://www.investing.com/instruments/HistoricalDataAjax"
head = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.183 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest'
}
payload = {
    'curr_id': '349',
'header': 'LHAG Historical Data',
'st_date': '01/01/2011',
'end_date': '12/31/2019',
'interval_sec': 'Monthly',
'sort_col': 'date',
'sort_ord': 'DESC',
'action': 'historical_data',
}
result = requests.post(url, headers = head, data = payload)
result.status_code
temp = BeautifulSoup(result.text)
stockdata = pd.read_html(str(temp.find('table')))[0]
for i in range(len(stockdata['Date'])):
    if stockdata['Date'][i].split()[0] == 'Jan':
        stockdata['Date'][i] = '20'+stockdata['Date'][i].split()[1]+'. 01. 25.'
    elif stockdata['Date'][i].split()[0] == 'Feb':
        stockdata['Date'][i] = '20'+stockdata['Date'][i].split()[1]+'. 02. 25.'
    elif stockdata['Date'][i].split()[0] == 'Mar':
        stockdata['Date'][i] = '20'+stockdata['Date'][i].split()[1]+'. 03. 25.'
    elif stockdata['Date'][i].split()[0] == 'Apr':
        stockdata['Date'][i] = '20'+stockdata['Date'][i].split()[1]+'. 04. 25.'
    elif stockdata['Date'][i].split()[0] == 'May':
        stockdata['Date'][i] = '20'+stockdata['Date'][i].split()[1]+'. 05. 25.'
    elif stockdata['Date'][i].split()[0] == 'Jun':
        stockdata['Date'][i] = '20'+stockdata['Date'][i].split()[1]+'. 06. 25.'
    elif stockdata['Date'][i].split()[0] == 'Jul':
        stockdata['Date'][i] = '20'+stockdata['Date'][i].split()[1]+'. 07. 25.'
    elif stockdata['Date'][i].split()[0] == 'Aug':
        stockdata['Date'][i] = '20'+stockdata['Date'][i].split()[1]+'. 08. 25.'
    elif stockdata['Date'][i].split()[0] == 'Sep':
        stockdata['Date'][i] = '20'+stockdata['Date'][i].split()[1]+'. 09. 25.'
    elif stockdata['Date'][i].split()[0] == 'Oct':
        stockdata['Date'][i] = '20'+stockdata['Date'][i].split()[1]+'. 10. 25.'
    elif stockdata['Date'][i].split()[0] == 'Nov':
        stockdata['Date'][i] = '20'+stockdata['Date'][i].split()[1]+'. 11. 25.'
    elif stockdata['Date'][i].split()[0] == 'Dec':
        stockdata['Date'][i] = '20'+stockdata['Date'][i].split()[1]+'. 12. 25.'
stockdata.to_excel(excel_writer=r'C:\Users\com\[MSB535]\data\Breau Data\stock_luft.xlsx')
# Out:
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import traceback
import statsmodels.api as sm
from matplotlib import pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
data =pd.read_csv(r'C:\Users\com\[MSB535]\data\Breau Data\Data.csv')

# %%
company_name = []
for keys in data['UNIQUE_CARRIER_NAME']:
    if keys in company_name :
        continue
    else :
        company_name.append(keys)

# %%
company_name
# Out:
# ['Asia Pacific',
#  'Varig S. A.',
#  'Qantas Airways Ltd.',
#  'Cargolux Airlines International S.A',
#  'United Air Lines Inc.',
#  'ExpressJet Airlines Inc.',
#  'Tatonduk Outfitters Limited d/b/a Everts Air Alaska and Everts Air Cargo',
#  'Polar Air Cargo Airways',
#  'Martinair Holland N.V.',
#  'El Al Israel Airlines Ltd.',
#  'Northwest Airlines Inc.',
#  'Federal Express Corporation',
#  'United Parcel Service',
#  'Kitty Hawk International',
#  'Nippon Cargo Airlines',
#  'Japan Air Lines Co. Ltd.',
#  'Korean Air Lines Co. Ltd.',
#  'Amerijet International',
#  'Sterling Cargo',
#  'Evergreen International Inc.',
#  'Compagnie Natl Air France',
#  'Compagnia Aerea Italiana',
#  'Lufthansa German Airlines',
#  'Arrow Air Inc.',
#  'China Airlines Ltd.',
#  'Eva Airways Corporation',
#  'Reliant Airlines',
#  'Pace Airlines',
#  'North American Airlines',
#  'Sky Trek International Airlines',
#  'Falcon Air Express',
#  'Capital Cargo International',
#  'Express One International Inc.',
#  'Astar USA, LLC',
#  'Air Transport International',
#  'Kitty Hawk Aircargo',
#  'Emery Worldwide Airlines',
#  'USA Jet Airlines Inc.',
#  'Transportes Aereos Mercantiles Panamericanos S.A',
#  'Miami Air International',
#  'ABSA-Aerolinhas Brasileiras',
#  'Fine Airlines Inc.',
#  'Continental Air Lines Inc.',
#  'Centurion Cargo Inc.',
#  'Aero Transcolombiana',
#  'America West Airlines Inc.',
#  'Gemini Air Cargo Airways',
#  'Singapore Airlines Ltd.',
#  'Saudi Arabian Airlines Corp',
#  'Heavylift Cargo Airlines Lt',
#  'Tower Air Inc.',
#  'Lynden Air Cargo Airlines',
#  'Express.Net Airlines',
#  'TransMeridian Airlines',
#  'Bradley Air Services Ltd.',
#  'Champion Air',
#  'Sun Country Airlines d/b/a MN Airlines',
#  'Aer Turas Teoranta',
#  'Delta Air Lines Inc.',
#  'Atlas Air Inc.',
#  'Swissair Transport Co. Ltd.',
#  'Lan-Chile Airlines',
#  'Florida West Airlines Inc.',
#  'Iberia Air Lines Of Spain',
#  'Continental Micronesia',
#  'Aeromexico',
#  'Aeromexpress',
#  'Aerotransportes Mas De Crga',
#  'Caribbean Airlines Limited',
#  'Lineas Aereas Suramerican',
#  'Serv De Trans Aereos Fuegui',
#  'Turks Air Ltd.',
#  'Taca International Airlines',
#  'Aerolineas Uruguayas S.A.',
#  'Surinam Airways Limited',
#  'DHL Aero Expresso',
#  'Renown Aviation',
#  'Antonov Company',
#  'Translux Intl Airlines',
#  'Cathay Pacific Airways Ltd.',
#  'Air China',
#  'Asiana Airlines Inc.',
#  'China Eastern Airlines',
#  nan,
#  'China Southern Airlines',
#  'World Airways Inc.',
#  'Frontier Airlines Inc.',
#  'Ryan International Airlines',
#  'Volga-Dnepr Airlines',
#  "Airbus Transport Internat'l",
#  'Mesaba Airlines',
#  'Southern Air Inc.',
#  'Compania Panamena (Copa)',
#  'Ameristar Air Cargo',
#  'Trans-Air-Link Corporation',
#  'ATA Airlines d/b/a ATA',
#  'Kalitta Air LLC',
#  'Klm Royal Dutch Airlines',
#  'Aloha Airlines Inc.',
#  'Britannia Airways Ltd.',
#  'Air Canada',
#  'Mytravel Airways',
#  'First Choice Airways',
#  'Southeast Airlines',
#  'Air New Zealand',
#  'American Airlines Inc.',
#  'British Airways Plc',
#  'Cargojet Airways Ltd.',
#  'Air Aruba',
#  'Finnair Oy',
#  'Aerovias Nacl De Colombia',
#  'US Airways Inc.',
#  'Executive Airlines',
#  'Aviacsa Airlines',
#  'Biman Bangladesh Airlines',
#  'Horizon Air',
#  'Alaska Airlines Inc.',
#  'Trans World Airways LLC',
#  'Planet Airways',
#  'Lloyd Aereo Boliviano S. A.',
#  'Compania Mexicana De Aviaci',
#  'Royal Air Maroc',
#  'Canada 3000 Airlines Ltd.',
#  'Magadan Airlines',
#  'Lineas Aereas Allegro',
#  'Jazz Aviation LP',
#  'Soc.Nouvelle Air Guadeloupe',
#  'Air Jamaica Limited',
#  'Aerolineas Argentinas',
#  'Aero California',
#  'South African Airways',
#  'Monarch Airlines',
#  'Tarom Romanian Air Transpor',
#  'Kuwait Airways Corp.',
#  'Condor Flugdienst',
#  'Viacao Aerea Sao Paulo',
#  'Dutch Caribbean Airlines',
#  'Lorair Ltd.',
#  'Comair Inc.',
#  'Envoy Air',
#  'Aeroflot Russian Airlines',
#  'Servicios Avensa',
#  'Royal Air',
#  'ExpressJet Airlines LLC',
#  'Pan American Airways Corp.',
#  'Alia-(The) Royal Jordanian',
#  'Tap-Portuguese Airlines',
#  'Canadian Airlines International Ltd.',
#  'Cayman Airways Limited',
#  'Ecuatoriana De Aviacion',
#  'Bahamasair Holding Limited',
#  'Sunworld International Airlines',
#  'Air Transat',
#  'Lacsa',
#  'Airbc Ltd.',
#  'Pakistan International Airlines',
#  'AirTran Airways Corporation',
#  'Aeropostal Alas De Venezuel',
#  'Luftransport-Unternehmen',
#  'Air Afrique',
#  'Aerovias Venezolanas-Avensa',
#  'Air Europa',
#  'City Bird',
#  'Lb Limited',
#  'Air Liberte Aka Aom Minerve',
#  'Corse Air International',
#  'Polskie Linie Lotnicze',
#  'Ghana Airways Corporation',
#  'Polynesian Airlines Ltd.',
#  'National Aviation Company of India Limited d/b/a Air India',
#  'Transbrasil S.A.',
#  'Air Nauru',
#  'Aer Lingus Plc',
#  'Air Comet S.A.',
#  'Sky Service F.B.O.',
#  'Omni Air International LLC',
#  'Balair Ag',
#  'Midwest Airline, Inc.',
#  'Egyptair',
#  'XTRA Airways',
#  'Virgin Atlantic Airways',
#  'Aeroejecutivo S.A.',
#  'Air Tahiti Nui',
#  'Uzbekistan Airways',
#  'Transportes Aeros Meridiona',
#  'Air Europe S.P.A.',
#  'Turk Hava Yollari A.O.',
#  'Air Malta',
#  'Sabena Belgian World Air.',
#  'Philippine Airlines Inc.',
#  'Icelandair',
#  'Aero Continente',
#  'Hawaiian Airlines Inc.',
#  'Harlequin Air Corporation',
#  'Lapa-Lineas Aereas Privadas',
#  'Scandinavian Airlines Sys.',
#  'Jalways Co. Ltd.',
#  'Guyana Airways Corporation',
#  'Aces Airlines',
#  'Austrian Airlines',
#  'Air Pacific Ltd.',
#  'Ethiopian Airlines',
#  'Malaysian Airline System',
#  'Lauda Air Luftfahrt Ag',
#  'Olympic Airways',
#  'Aviateca',
#  'Lan Peru Airlines',
#  'All Nippon Airways Co.',
#  'Thai Airways International Ltd.',
#  'Thomas Cook Airlines Uk Ltd.',
#  'Spanair S.A.',
#  'Czech Airlines',
#  'Malev Hungarian Airlines',
#  'Zantop International',
#  'C.A.L Cargo Airlines',
#  'Avia Leasing Company',
#  'Polyot Airlines',
#  'British Midland Airways Ltd.',
#  'Privatair',
#  'Taca Peru',
#  'TUIfly Nordic A.B.',
#  'USA 3000 Airlines',
#  'Air Japan Co',
#  'Hapag Lloyd Flug.',
#  'Midway Airlines Inc.',
#  'Sky Lease Cargo',
#  'Independence Air',
#  'ABX Air Inc',
#  'Air Atlanta Icelandic',
#  'Northern Air Cargo Inc.',
#  'Cielos De Peru',
#  'All Canada Express',
#  'MK Airlines Ltd.',
#  'Vensecar International',
#  'Global Supply System',
#  'Sky King Inc.',
#  'SkyWest Airlines Inc.',
#  'Estafeta Carga Aereas',
#  'Empire Airlines Inc.',
#  'Commutair Aka Champlain Enterprises, Inc.',
#  'Venture Travel LLC d/b/a Taquan Air Service',
#  'Edelweiss Air Ag',
#  'Island Air Service',
#  'Larrys Flying Service',
#  'Grant Aviation',
#  'Air Wisconsin Airlines Corp',
#  'Hageland Aviation Service',
#  'Frontier Flying Service',
#  'Bering Air Inc.',
#  'Olson Air Service',
#  'Smokey Bay Air Inc.',
#  'Seaport Airlines, Inc.',
#  'Mesa Airlines Inc.',
#  'Katmai Air',
#  'Aerolitoral',
#  'Allegheny Airlines',
#  'G5 Executive Ag',
#  'Spernak Airways Inc.',
#  'Kenmore Air Harbor',
#  'Endeavor Air Inc.',
#  'Boston-Maine Airways',
#  'Promech',
#  'Ward Air',
#  'Iliamna Air Taxi',
#  'Cape Smythe Air Service',
#  'Vintage Props & Jets Inc.',
#  'PSA Airlines Inc.',
#  'Corvus Airlines, Inc d/b/a Era Aviation d/b/a Ravn Alaska',
#  'Piedmont Airlines',
#  'Skyway Airlines',
#  'Skagway Air Service',
#  'Peninsula Airways Inc.',
#  'Chautauqua Airlines Inc.',
#  'Silver Airways',
#  'Samoa Aviation Inc.',
#  'Lineas Aereas Azteca',
#  'Cape Air',
#  'Allegiant Air',
#  'Helijet International Inc.',
#  'Flying Boat Inc.',
#  'Westjet',
#  'Transportes Aereos De Cabo',
#  'Swiss International Airlines',
#  'Sol Air (Aero Hunduras)',
#  'Harmony Airways',
#  'Regency Air',
#  'Custom Air Transport',
#  'Freedom Airlines d/b/a HP Expr',
#  'Nolinor Aviation',
#  'Air St. Thomas',
#  'Gulf And Caribbean Cargo',
#  'Lan Ecuador',
#  'NetJets Large Aircraft Company L.L.C.',
#  'Alaska Central Express',
#  'Triair Bermuda Flt Operations',
#  'Caribbean Sun Airlines, Inc. d/b/a World Atlantic Airlines',
#  'Spirit Air Lines',
#  'Mountain Bird/Salmon Air',
#  'Aerosvit Ukranian Airlines',
#  'Sierra Pacific Airlines',
#  'Trans States Airlines',
#  'Jetsgo',
#  'Lan Dominica',
#  'Sata Internacional',
#  'China Cargo Airline',
#  'Air North',
#  'SkyLink Express Inc.',
#  'Ryan Air f/k/a Arctic Transportation',
#  'Air Georgian',
#  'Propair',
#  'Air Midwest Inc.',
#  'Aeroservices Executive',
#  'Victory Air Transport Inc.',
#  'Florida Coastal Airlines',
#  'Belair Airlines Ltd.',
#  'Primaris Airlines Inc.',
#  'Canjet Airlines',
#  'Euro Atlantic Airways',
#  'JetBlue Airways',
#  'Air Atlanta Europe',
#  'Emirates',
#  'Omega Air Holdings d/b/a Focus Air',
#  'National Air Cargo Group Inc d/ba National Airlines',
#  'Hong Kong Dragonair',
#  'Aerounion Aerotransporte de Carga Union SA de CV',
#  'Transmile Air Service',
#  'Varig Logistica S/A',
#  'MAXjet',
#  'Homer Air',
#  'Abaco Air, Ltd.',
#  'Challenge Air Luftverkehrs GmbH',
#  'Tyrolean Jet Service',
#  'Aero-Services-Corporate',
#  'Shuttle America Corp.',
#  'EOS Airlines, Inc.',
#  'Excel Airways',
#  'Freedom Air',
#  'Aerodynamics Inc. d/b/a SkyValue d/b/a SkyValue Airways',
#  'Israir Airlines',
#  'Arrow Panama',
#  'ANA & JP Express Co. Ltd.',
#  'Kalitta Charters II',
#  'Cargo 360, Inc.',
#  'Tradewind Aviation',
#  'Colgan Air',
#  'Comlux Aviation, AG',
#  'Swift Air, LLC d/b/a Eastern Air Lines d/b/a Eastern',
#  'Jet Connection Businessflight Ag',
#  'Eurofly S.p.A',
#  'L.A.B. Flying Service Inc.',
#  'Jetstar Airways Pty Limited',
#  'Etihad Airways',
#  'TravelspanGT, Inc. S.A.',
#  'Globespan Airways Limited d/b/a Flyglobespan',
#  'LAN Argentina',
#  'TUI Airlines Nederland B.V.',
#  'Master Top Linhas Aereas, Ltda.',
#  'ACM AIR CHARTER GmbH',
#  'Seaborne Virgin Islands, Inc.',
#  'JetClub AG',
#  'Global Jet Luxembourg, Sa',
#  'Metropix UK, LLP.',
#  'DCA',
#  'Big Sky Airlines Inc.',
#  'CAT Aviation',
#  'VistaJet Luftfahrtunternehmen GmbH',
#  'Dynamic Aviation, Inc. d/b/a Beacon',
#  'Pacific Airways, Inc.',
#  'Laudamotion GmbH',
#  'Global Jet Austria, GmbH',
#  'Wright Air Service',
#  'Compass Airlines',
#  'Polar Airlines de Mexico d/b/a Nova Air',
#  'Skyservice Airlines, Inc.',
#  'Flair Airlines Ltd.',
#  'Republic Airline',
#  'Jet Airways (India) Limited',
#  'Vladivostok Air',
#  'Titan Airways',
#  'Qatar Airways (Q.C.S.C)',
#  'Flyjet Limited d/b/a Silverjet',
#  "Elysair d/b/a L'Avion",
#  'Santa Barbara Airlines, C.A',
#  'Great Wall Airlines Company Limited',
#  'Star Air A/S',
#  'TAG Aviation S.A.',
#  'JetAlliance Flugbetriebs d/b/a JAF Airservice',
#  'TAG Aviation Espana S.L.',
#  'Aeromexico Travel',
#  'Porter Airlines, Inc.',
#  'Corporatejets, XXI',
#  'Vision Airlines',
#  'Hainan Airlines Company Limited',
#  'Pan American World Airways Dominicana',
#  'Open Skies',
#  'Insel Air International B V',
#  'Jet2.com',
#  'Aerosur',
#  'Aeroenlaces Nacionales, S.A. de C.V. d/b/a VivaAerobus',
#  'Prescott Support Company, Inc.',
#  'Lan Colombia',
#  'Yangtze River Express Airlines Company',
#  'Avjet Corporation',
#  'Ocean Sky (UK) Limited',
#  'Jet Aviation Business Jets AG',
#  'Comlux Malta, Ltd.',
#  'TAG Aviation (UK) Ltd.',
#  'Sunwing Airlines Inc.',
#  'Virgin Blue International Airlines t/a V Australia',
#  'Concesionaria Vuela Compania De Aviacion SA de CV (Volaris)',
#  'Air Berlin PLC and CO',
#  'Air Greco, Inc., d/b/a Wings Air',
#  'XL Airways France',
#  'Aerolineas Galapagos S A Aerogal',
#  'AeroLogic GmbH',
#  'AirBridgeCargo Airlines Limited',
#  'Chartright Air Inc.',
#  'London Air Services Limited',
#  'Unijet',
#  'Swiss Air Ambulance',
#  'Air Alsie A/S',
#  'Flying Service N.V.',
#  'Hapag-Lloyd Executive GmbH',
#  'Acropolis Aviation Ltd.',
#  'ABS JETS A.S',
#  'Albinati Aeronautics SA',
#  'Warbelow',
#  'Corsair International',
#  'GoJet Airlines LLC d/b/a United Express',
#  'Aerovias de Intergracian Regional',
#  'Virgin America',
#  'Airitaly S.P.A.',
#  'Skymark Airlines Inc.',
#  'Transaero Airlines',
#  'Jin Air Co Ltd.',
#  'Exec Direct Aviation Services Limited',
#  'International Jet Management GmbH',
#  'Jet link AG',
#  'Air Sunshine Inc.',
#  'Transportes Aeromar S.A de C.V',
#  'Via Airlines d/b/a Charter Air Transport',
#  'Eastern Airlines f/k/a Dynamic Airways, LLC',
#  'TUI Airlines Belgium N.V. d/b/a Jetairfly',
#  'Arik Air International',
#  'Sichuan Airlines Co Ltd.',
#  'ABC Aerolineas SA de CV dba Interjet',
#  'Island Airlines LLC',
#  'Bertelsmann Aviation GmbH',
#  'Yute Air Aka Flight Alaska',
#  'Air Company Yakutia',
#  'VRG Linhas Aereas S A',
#  'Southwest Airlines Co.',
#  'Avior Airlines, C.A.',
#  'Brussels Airlines N.V.',
#  'Cargolux Italia SpA',
#  'Gainjet Aviation SA',
#  'Fly Jamaica Airways Limited',
#  'KaiserAir, Inc.',
#  'Norwegian Air Shuttle ASA',
#  'Air Canada rouge LP',
#  'Sky Regional Airlines Inc.',
#  'Tame Linea Aerea del Ecuador Tme EP',
#  'Western Global',
#  'Air Charter, Inc d/b/a Air Flamenco',
#  'Orange Air',
#  'CFM Inc d/b/a Contour Airlines d/b/a One Jet Shuttle',
#  'Dassault Falcon Service',
#  'Blue Jet SP Z o o',
#  'Comlux Aruba NV',
#  'Compagnie Aerienne Inter Regionale Express dba Air Antilles Express & Air Guyane',
#  'Azerbaijan Airlines CJSC',
#  'Ukraine International Airlines',
#  'Inselair Aruba NV',
#  'Eastern Airlines Group Inc.',
#  'Silk Way West Airlines',
#  'Oceanair Linhas Aereas S A',
#  'Inter Island Airways, d/b/a Inter Island Air',
#  'Cavok Air LLC',
#  'VistaJet Limited',
#  'Longtail Aviation Ltd.',
#  'Mjet GmbH',
#  'Albinati aviation Limited',
#  'Songbird Airways Inc.',
#  'Azul Linhas Aereas Brazileiras S A',
#  'WOW Air ehf',
#  'Fast Colombia SAS d/b/a Viva Colombia',
#  'Jet Aviation Flight Services, Inc.',
#  'Cargologicair Limited',
#  'Abelag Aviation AG',
#  'Luxaviation S A',
#  'Trans Northern Airways d/b/a Air Unlimited Charter Services',
#  'Svenskt Industriflyg AB',
#  'Talofa Airways Limited',
#  'Air Philippines Corp d/b/a Airphil Express, Philippines Airlines',
#  'Xiamen Airlines Co., Ltd.',
#  'Eastar Jet Co Ltd.',
#  'Eurowings GmbH',
#  'Hong Kong Express Airways Limited',
#  'Air Serbia',
#  'Hong Kong Airlines Limited',
#  'Air Hamburg Luftverkehrsgesellschaft mbH',
#  'Elite Airways LLC',
#  'Norwegian Air International Ltd.',
#  'Scoot Tigerair Pte Ltd d/b/a Scoot',
#  'Evelop Airlines SL',
#  'Air Asia X Berhad dba Airasia X',
#  'Beijing Capital Airlines',
#  'Tropic Ocean Airways LLC',
#  'Hillwood Airways, LLC  f/k/a   ATX Air Services, LLC',
#  'Polaris Aviation Solutions, LLC',
#  'Cebu Air Inc d/b/a Cebu Pacific Air',
#  'Flying Group Lux S.A.',
#  'Air Excursions LLC',
#  'Skyfirst Limited',
#  'Laudamotion Executive',
#  'Glock Aviation GmbH',
#  'Scott Air LLC dba Island Air Express',
#  'Nealco Air Charter Services, Inc.  d/b/a  Watermakers Air',
#  'Tantalus Air Ltd. d/b/a Harbour Air d/b/a Harbour Air Seaplanes',
#  'Primera Air Scandinavia',
#  'Jeju Air Co Ltd.',
#  'Norwegian Air UK Limited',
#  'Kenya Airways PLC',
#  'French bee',
#  'Vuela Aviacion, S.A.',
#  'OPENSKIES SAS',
#  'Aviateca, S.A.',
#  'Challenge Airlines (BE) S.A.',
#  'Scott Aviation, LLC  d/b/a  Silver Air',
#  'European Air Transport Leipzig GmbH',
#  'FAI rent-a-jet AG',
#  'Hyperion Aviation Ltd. dba Hyperion',
#  'Gestair, S.A.',
#  'Prince Aviation',
#  'Elitavia Malta Limited',
#  'TAG Aviation (Malta) Ltd.',
#  'Volkswagen AirSevice GmbH dba Volkswagon',
#  'Luxaviation Germany GmbH',
#  'Concierge U Ltd. d/b/a Jet Concierge Club',
#  'ADVANCED AIR, LLC',
#  'SWOOP Inc.']

# %%
for lines in company_name:
    if 'Lufthansa' in lines:
        print(lines)
# Out:
# Lufthansa German Airlines
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-367e9ec029b5> in <module>
#       1 for lines in company_name:
# ----> 2     if 'Lufthansa' in lines:
#       3         print(lines)
#
# TypeError: argument of type 'float' is not iterable

# %%
company = 'Lufthansa German Airlines'
savename= 'Deltaair'

# %%
info = []
threeones = ['1','3','5','7','8','10','12']
thirtys = ['4','6','9','11']
twoeights = ['2']
year = 2000
month = 1
is_company = data['UNIQUE_CARRIER_NAME'] == company
for i in range(21):
    month = 1
    for j in range(12):
        is_month = data['MONTH'] == month
        is_year = data['YEAR'] == year
        classifier = is_company & is_month & is_year
        passengers = data[classifier]['PASSENGERS'].sum()
        freight = data[classifier]['FREIGHT'].sum() + data[classifier]['MAIL'].sum()
        if str(month) in twoeights:
            date = str(year)+'. 0'+str(month)+'. 25.'
        elif str(month) in thirtys:
            if len(str(month)) == 1:
                date = str(year)+'. 0'+str(month)+'. 25.'
            else:
                date = str(year)+'. '+str(month)+'. 25.'
        elif str(month) in threeones:
            if len(str(month)) == 1:
                date = str(year)+'. 0'+str(month)+'. 25.'
            else:
                date = str(year)+'. '+str(month)+'. 25.'
        info.append([company, year, month, date, passengers, freight])
        month += 1
    year += 1
temp = pd.DataFrame(info,columns = ['Company','Year','Month','Date','Passenger','Freight'])
table = temp[temp['Passenger']!=0]
globals()['table_{}'.format(savename)]=table

# %%
stockdata =pd.read_excel(r'C:\Users\com\[MSB535]\data\Breau Data\stock_luft.xlsx')

# %%
year = 20
while True:
    if year == 0:
        break
    count = 0
    for i in range(len(stockdata['Date'])):
        if stockdata['Date'][i].split()[0].rstrip('.')[2:4].lstrip('0') == str(year):
            count +=1
    if count < 12:
        print('Year of ' + str(year)+' has lower month by '+str(count))
    year = year-1
# Out:
# Year of 20 has lower month by 0
# Year of 10 has lower month by 0
# Year of 9 has lower month by 0
# Year of 8 has lower month by 0
# Year of 7 has lower month by 0
# Year of 6 has lower month by 0
# Year of 5 has lower month by 0
# Year of 4 has lower month by 0
# Year of 3 has lower month by 0
# Year of 2 has lower month by 0
# Year of 1 has lower month by 0

# %%
floated = []
for i in range(len(stockdata['Change %'])):
    floated.append(float(stockdata['Change %'].values[i].rstrip('%')))
stockdata['Change(float)'] = floated

# %%
newdate = []
for i in range(len(table_Deltaair['Date'])):
    date = ''
    for j in range(3):
        if j == 2:
            date += table_Deltaair['Date'].values[i].split()[j].strip().rstrip('.')
        else:
            date += table_Deltaair['Date'].values[i].split()[j].strip().rstrip('.')+'-'
    newdate.append(date)
table_Deltaair['newdate'] = newdate
temp = table_Deltaair[table_Deltaair['Year']<2020]
table_Deltaair = temp
# Out:
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
def plot_df(df, x, y, title="", xlabel='Date', ylabel='Value', dpi=100,colors = 'color'):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color=colors)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.xticks(np.arange(0,len(x),step = 30),x[np.arange(0,len(x),step = 30)])
    plt.show()

# %%
what = 'Freight'
ts_Deltaair = pd.DataFrame(table_Deltaair[what].values,index = table_Deltaair['Date'],columns = [what])
plot_df(ts_Deltaair, x=ts_Deltaair.index, y=ts_Deltaair[what].values, title='Monthly {}'.format(what), colors = 'tab:Blue')

# %%
what = 'Passenger'
ts_Deltaair = pd.DataFrame(table_Deltaair[what].values,index = table_Deltaair['Date'],columns = [what])
plot_df(ts_Deltaair, x=ts_Deltaair.index, y=ts_Deltaair[what].values, title='Monthly {}'.format(what), colors = 'tab:red')

# %%
what = 'Price'
#Price or Change(float'
stock_Deltaair = pd.DataFrame(stockdata.loc[::-1][what].values,index = stockdata.loc[::-1]['Date'],columns = [what])
plot_df(stock_Deltaair, x=stock_Deltaair.index, y=stock_Deltaair[what].values, title='Monthly Stock Price',colors = 'tab:Green')

# %%
what = 'Change(float)'
#Price or Change(float)'
stock_Deltaair = pd.DataFrame(stockdata.loc[::-1][what].values,index = stockdata.loc[::-1]['Date'],columns = [what])
plot_df(stock_Deltaair, x=stock_Deltaair.index, y=stock_Deltaair[what].values, title='Monthly Stock Price Change %',colors = 'tab:Green')

# %%
import statsmodels.api as sm
from datetime import datetime
from pylab import rcParams

# %%
datetime = []
for i in range(len(table_Deltaair['newdate'])):
    datetime.append(pd.to_datetime(table_Deltaair['newdate'].values[i], format='%Y-%m-%d'))
table_Deltaair['datetime'] = datetime
# Out:
# C:\Users\com\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
what = 'Freight'
temp = pd.DataFrame(table_Deltaair[what].values,index = table_Deltaair['datetime'],columns = [what])
ts_Deltaair = temp[temp[what] !=0]
rcParams['figure.figsize'] = 18, 10
rcParams['figure.dpi'] = 100
decomposition = sm.tsa.seasonal_decompose(ts_Deltaair, model='additive', freq = 12)
decomposition.plot()

# %%
temp = sm.tsa.seasonal_decompose(ts_Deltaair, model='additive', freq = 12).trend
table_trend = temp[temp[what].notnull()]
newdate = []
for i in range(len(stockdata['Date'])):
    date = ''
    for j in range(len(stockdata['Date'][i].split())):
        if j == 2:
            date += stockdata['Date'][i].split()[j].strip().rstrip('.')
        else:
            date += stockdata['Date'][i].split()[j].strip().rstrip('.')+'-'
    newdate.append(date)
stockdata['newdate'] = newdate
datetime = []
for i in range(len(stockdata['Date'])):
    datetime.append(pd.to_datetime(stockdata['newdate'][i], format='%Y-%m-%d'))
stockdata['datetime'] = datetime
stockdata.head()
price = []
date = []
for i in range(len(table_trend)):
    if stockdata[stockdata['datetime'] == table_trend.index[i]]['Price'].size != 0:
        price.append(stockdata[stockdata['datetime'] == table_trend.index[i]]['Price'].values)          
        date.append(table_trend.index[i])
chart_info = pd.DataFrame(price, index = date, columns = ['Price'])
chart_info[what] = table_trend[what]
chart_info.to_excel(excel_writer=r'C:\Users\com\[MSB535]\data\Breau Data\{} {}.xlsx'.format(company,what))

# %%
line = LinearRegression()
y_value = chart_info['Price']
x_value = chart_info[what].values
line.fit(x_value.reshape(-1,1),y_value)
plt.plot(x_value, y_value, 'o')
plt.plot(x_value,line.predict(x_value.reshape(-1,1)), color = 'green')
plt.title('{}(Cargo)'.format(company), fontsize = 15)
plt.xlabel('Cargo_trend', fontsize = 15)
plt.ylabel('Stock Price', fontsize = 15)
plt.show()

# %%
x_value = sm.add_constant(x_value,has_constant='add')
model = sm.OLS(y_value,x_value)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.2226
# Date:                Mon, 21 Dec 2020   Prob (F-statistic):              0.638
# Time:                        14:15:40   Log-Likelihood:                -306.81
# No. Observations:                 102   AIC:                             617.6
# Df Residuals:                     100   BIC:                             622.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         21.0323     11.522      1.825      0.071      -1.827      43.891
# x1         -1.056e-07   2.24e-07     -0.472      0.638    -5.5e-07    3.38e-07
# ==============================================================================
# Omnibus:                       17.942   Durbin-Watson:                   0.104
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.069
# Skew:                           1.061   Prob(JB):                     2.66e-05
# Kurtosis:                       3.675   Cond. No.                     1.21e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.21e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
dt_min = table_Deltaair['Date'] >= stockdata.tail(1)['Date'].values[0]
dt_max = table_Deltaair['Date'] <= stockdata.head(1)['Date'].values[0]
dt_between = dt_min & dt_max

# %%
what = 'Freight'
y_value = stockdata['Price'].values[0:189]
x_value = table_Deltaair[dt_between].loc[::-1][what].values[0:189]
line = LinearRegression()
line.fit(x_value.reshape(-1,1),y_value)
plt.plot(x_value, y_value, 'o')
plt.plot(x_value,line.predict(x_value.reshape(-1,1)), color = 'green')
plt.title('{}(Cargo)'.format(company), fontsize = 15)
plt.xlabel('Cargo', fontsize = 15)
plt.ylabel('Stock Price', fontsize = 15)
plt.show()

# %%
x_value = sm.add_constant(x_value,has_constant='add')
model = sm.OLS(y_value,x_value)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.2340
# Date:                Mon, 21 Dec 2020   Prob (F-statistic):              0.630
# Time:                        14:15:53   Log-Likelihood:                -321.96
# No. Observations:                 108   AIC:                             647.9
# Df Residuals:                     106   BIC:                             653.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.9826      4.973      3.616      0.000       8.123      27.843
# x1         -4.687e-08   9.69e-08     -0.484      0.630   -2.39e-07    1.45e-07
# ==============================================================================
# Omnibus:                       20.352   Durbin-Watson:                   0.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.791
# Skew:                           1.099   Prob(JB):                     4.14e-06
# Kurtosis:                       3.824   Cond. No.                     5.51e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.51e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
what = 'Passenger'
temp = pd.DataFrame(table_Deltaair[what].values,index = table_Deltaair['datetime'],columns = [what])
ts_Deltaair = temp[temp[what] !=0]
rcParams['figure.figsize'] = 18, 10
rcParams['figure.dpi'] = 100
decomposition = sm.tsa.seasonal_decompose(ts_Deltaair, model='additive', freq = 12)
decomposition.plot()

# %%
temp = sm.tsa.seasonal_decompose(ts_Deltaair, model='additive', freq = 12).trend
table_trend = temp[temp[what].notnull()]
newdate = []
for i in range(len(stockdata['Date'])):
    date = ''
    for j in range(len(stockdata['Date'][i].split())):
        if j == 2:
            date += stockdata['Date'][i].split()[j].strip().rstrip('.')
        else:
            date += stockdata['Date'][i].split()[j].strip().rstrip('.')+'-'
    newdate.append(date)
stockdata['newdate'] = newdate
datetime = []
for i in range(len(stockdata['Date'])):
    datetime.append(pd.to_datetime(stockdata['newdate'][i], format='%Y-%m-%d'))
stockdata['datetime'] = datetime
stockdata.head()
price = []
date = []
for i in range(len(table_trend)):
    if stockdata[stockdata['datetime'] == table_trend.index[i]]['Price'].size != 0:
        price.append(stockdata[stockdata['datetime'] == table_trend.index[i]]['Price'].values)          
        date.append(table_trend.index[i])
chart_info = pd.DataFrame(price, index = date, columns = ['Price'])
chart_info[what] = table_trend[what]
chart_info.to_excel(excel_writer=r'C:\Users\com\[MSB535]\data\Breau Data\{} {}.xlsx'.format(company,what))

# %%
line = LinearRegression()
y_value = chart_info['Price'][0:195]
x_value = chart_info[what].values[0:195]
line.fit(x_value.reshape(-1,1),y_value)
plt.plot(x_value, y_value, 'o')
plt.plot(x_value,line.predict(x_value.reshape(-1,1)), color = 'green')
plt.title('{}(Passenger)'.format(company), fontsize = 15)
plt.xlabel('{}_Trend'.format(what), fontsize = 15)
plt.ylabel('Stock Price', fontsize = 15)
plt.show()

# %%
x_value = sm.add_constant(x_value,has_constant='add')
model = sm.OLS(y_value,x_value)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.441
# Model:                            OLS   Adj. R-squared:                  0.435
# Method:                 Least Squares   F-statistic:                     78.83
# Date:                Mon, 21 Dec 2020   Prob (F-statistic):           2.83e-14
# Time:                        14:16:02   Log-Likelihood:                -277.28
# No. Observations:                 102   AIC:                             558.6
# Df Residuals:                     100   BIC:                             563.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -32.8967      5.475     -6.009      0.000     -43.758     -22.035
# x1             0.0001   1.18e-05      8.878      0.000    8.13e-05       0.000
# ==============================================================================
# Omnibus:                        4.959   Durbin-Watson:                   0.180
# Prob(Omnibus):                  0.084   Jarque-Bera (JB):                4.375
# Skew:                           0.487   Prob(JB):                        0.112
# Kurtosis:                       3.283   Cond. No.                     6.93e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.93e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
dt_min = table_Deltaair['Date'] >= stockdata.tail(1)['Date'].values[0]
dt_max = table_Deltaair['Date'] <= stockdata.head(1)['Date'].values[0]
dt_between = dt_min & dt_max

# %%
what = 'Passenger'
y_value = stockdata['Price'].values[0:189]
x_value = table_Deltaair[dt_between].loc[::-1][what].values[0:189]
line = LinearRegression()
line.fit(x_value.reshape(-1,1),y_value)
plt.plot(x_value, y_value, 'o')
plt.plot(x_value,line.predict(x_value.reshape(-1,1)), color = 'green')
plt.title('{}(Passenger)'.format(company), fontsize = 15)
plt.xlabel('{}'.format(what), fontsize = 15)
plt.ylabel('Stock Price', fontsize = 15)
plt.show()

# %%
x_value = sm.add_constant(x_value,has_constant='add')
model = sm.OLS(y_value,x_value)
result=model.fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.3264
# Date:                Mon, 21 Dec 2020   Prob (F-statistic):              0.569
# Time:                        14:16:07   Log-Likelihood:                -321.91
# No. Observations:                 108   AIC:                             647.8
# Df Residuals:                     106   BIC:                             653.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         14.2680      2.355      6.059      0.000       9.599      18.937
# x1          2.823e-06   4.94e-06      0.571      0.569   -6.97e-06    1.26e-05
# ==============================================================================
# Omnibus:                       21.218   Durbin-Watson:                   0.111
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.282
# Skew:                           1.111   Prob(JB):                     1.96e-06
# Kurtosis:                       3.952   Cond. No.                     2.42e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
chart_info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1fa257767997> in <module>
# ----> 1 chart_info
#
# NameError: name 'chart_info' is not defined
